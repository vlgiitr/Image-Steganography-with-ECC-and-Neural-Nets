# %%
import utils
import numpy as np
from ecc import G 
from ecc import bitcoin_curve as BC 
import ecc
import encrypt as encrypt
from ecc import key_length, public_key
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
import decrypt as decrypt

# %%
random_key = 18398800208287441760983961865782355938679551141855098527665653562118439265414
private_key = 3

# %%
encrypted_image = encrypt.encrypt_image('./images/lena.png')
print(encrypted_image.shape)
# Out:
# (512, 512, 3)

# %%
plt.imshow(encrypted_image, interpolation='nearest')
plt.show()
im = Image.fromarray((encrypted_image).astype(np.uint8))
im.save('./images/enc.png')

# %%
decrypted_image = decrypt.decrypt_image('./images/enc.png')

# %%
plt.imshow(decrypted_image, interpolation='nearest')
plt.show()
im = Image.fromarray((decrypted_image).astype(np.uint8))
im.save('./images/dec.png')

# %%
image, channels, length, width = encrypt.load_image('./images/dec.png')
pixels_list = encrypt.extract_channels(image, channels)
for i in pixels_list:
    i = i.reshape(512, 512)
    plt.imshow(i, interpolation='nearest')
    plt.show()

# %%
image, channels, length, width = encrypt.load_image('./images/dec.png')
plt.imshow(image)
